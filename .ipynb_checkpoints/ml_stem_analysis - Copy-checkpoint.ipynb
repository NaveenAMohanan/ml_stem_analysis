# %% [markdown]
# # R.O.C.K.S (RedCarpet Open Code and Kraft Series) task implemention
# Naveen A Mohanan 27/4/2018
#
# Email :menaveenam@gmail.com or naveen.am@yahoo.com
#
# Mno : 9599131811

# %% [markdown]
# ### STAGE 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_read = pd.read_excel('2010 Federal STEM Education Inventory Data Set.xls',header =1)
print ("Total (rows,col)=",data_read.shape,"\nSAMPLE")
data_read.head(5)
# Out:
# Total (rows,col)= (253, 256)
# SAMPLE
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %%
#checking values of col.
data_read.columns
# Out:
# Index(['Index Number', 'Investment Name', 'Agency', 'Subagency',
#        'A) Brief Description', 'B) Year Established', 'C1) Funding FY2008',
#        'C2) Funding FY2009', 'C3) Funding FY2010',
#        'D) Mission-specific or General STEM?',
#        ...
#        'Unnamed: 246', 'Unnamed: 247',
#        'Y3) Process or Implementation Evaluation Type', 'Unnamed: 249',
#        'Unnamed: 250', 'Y4) Portfolio Evaluation/Review Type', 'Unnamed: 252',
#        'Unnamed: 253', 'Y5) Expert Review Type', 'Unnamed: 255'],
#       dtype='object', length=256)

# %% [markdown]
#  Stage 1 Calculate % growth of funding between year 2008 & 2009 and add tag variable

# %%
per_change_df = pd.DataFrame()
per_change_df['Index Number'] = data_read['Index Number']
per_change_df['% change'] = ((data_read['C2) Funding FY2009'] - data_read['C1) Funding FY2008'])/data_read['C1) Funding FY2008'])
per_change_df['Tag'] = np.where(per_change_df['% change'] > 0, 1, 0)
per_change_df.head(5)
# Out:
#   Index Number  % change  Tag
# 0     PRG_0001  0.372137    1
# 1     PRG_0002  0.000000    0
# 2     PRG_0003  0.000000    0
# 3     PRG_0004  1.579869    1
# 4     PRG_0005  0.680982    1

# %%
#checking how many null values tag has 0 null so worked correctly 
per_change_df[per_change_df.columns[:]].isnull().sum()
# Out:
# Index Number     1
# % change        29
# Tag              0
# dtype: int64

# %%
#Merging to add % change and Tag at the end
per_change_df = data_read.merge(per_change_df,on='Index Number')
per_change_df.head(5)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %% [markdown]
# Stage 2:
# 1) Create graphs of univariate distribution of all non funding variables and share on a jupyter notebook. Just FYI - Funding FY2008, FY2009, FY2010 are the "funding variables"
#
# 2) Calculate mutual_info_score of target variable created in stage 1 & ALL non funding variables and share on a jupyter notebook.

# %% [markdown]
# ### Stage 2

# %% [markdown]
# Printing graph for all values except "funding variables"

# %%
# to plot univariate distribution 
def plot():
    attribute_list = data_read.columns.tolist() 
    x=0
    for i in attribute_list:
        if((i == 'C1) Funding FY2008') or (i == 'C2) Funding FY2009') or (i == 'C3) Funding FY2010') ):
            continue
        
        else:
            t=data_read[i].dropna()
            fig,ax=plt.subplots()
            plt.hist(t)
            ax.set_xlabel(i)
            ax.set_ylabel('count')
            plt.show(ax)
#plot()

# %%
#Calculating mutual_info_score
from sklearn import metrics
from sklearn import preprocessing
label=preprocessing.LabelEncoder()

# %%
# Converting string fields to no for analysis 
T = per_change_df
t = np.array(per_change_df['Tag']).ravel()
for i in T:      
    try:
        T[i]=label.fit_transform(T[i])
    except:
        T[i]=label.fit_transform(T[i].astype('str'))

variable=[]
v_score=[]
# calculating mutual_info_score
for i in T:
    if((i == 'C1) Funding FY2008') or (i == 'C2) Funding FY2009') or (i == 'C3) Funding FY2010') ):
        continue
        
    else:
        x=T[i].ravel()
        score=metrics.mutual_info_score(x,t)
        v_score.append(score)
        variable.append(i)  

Mutual_info=pd.DataFrame({'Variables':variable,'MI Score':v_score})
    
Mutual_info.head(5)
# Out:
#    MI Score             Variables
# 0  0.686563          Index Number
# 1  0.681084       Investment Name
# 2  0.094299                Agency
# 3  0.245920             Subagency
# 4  0.686563  A) Brief Description

# %% [markdown]
# ### Stage 3

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

# %%
#looking at metrix for deciding features and target 
#print ("Total (rows,col)=",T.shape,)
#T.columns

# %%
#print(X)
#print(y)
#TO check taking correct feature and target uncomment above lines

# %%
# matrix of features 
X = T.iloc[:, 1:256].values
y = T.iloc[:, 257].values
#Divide data into train & test samples. (70-30 split)
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size = 0.3,random_state = 0 )

classifier = XGBClassifier()
classifier.fit(X_train,y_train,eval_metric='auc')

y_pred = classifier.predict(X_test)
Xtest_predprob = classifier.predict_proba(X_test)[:,1]
# checking roc_auc_score on test sample.
cm = confusion_matrix(y_test,y_pred)
print("Comfusion matrix\n ",cm)
print("AUC Score on test: %f" % metrics.roc_auc_score(y_test, Xtest_predprob))
# Out:
# Comfusion matrix
#   [[19 13]
#  [14 30]]
# AUC Score on test: 0.753551
# C:\Users\Naveen\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# XGB with more fine tuned parameters 
X = T.iloc[:, 1:256].values
y = T.iloc[:, 257].values

X_train, X_test, y_train,y_test = train_test_split(X, y, test_size = 0.3,random_state = 3 )
classifier = XGBClassifier(learning_rate =0.1,n_estimators=100,max_depth=5,min_child_weight=1,gamma=0,subsample=0.8,colsample_bytree=0.8,
 objective= 'binary:logistic')
classifier.fit(X_train,y_train,eval_metric='auc')

Xtest_predprob = classifier.predict_proba(X_test)[:,1]
cm = confusion_matrix(y_test,y_pred)
print("Comfusion matrix\n ",cm)
print("AUC Score on test: %f" % metrics.roc_auc_score(y_test, Xtest_predprob))
# Out:
# Comfusion matrix
#   [[16 24]
#  [17 19]]
# AUC Score on test: 0.784028
